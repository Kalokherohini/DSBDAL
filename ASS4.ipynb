# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("C:/Users/lenovo/Downloads/HousingData.csv")

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90    NaN  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99    NaN  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df.shape
# Out:
# (506, 14)

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df["CRIM"].fillna(df["CRIM"].mean(),inplace=True)
df["ZN"].fillna(df["ZN"].mean(),inplace=True)
df["INDUS"].fillna(df["INDUS"].mean(),inplace=True)
df["CHAS"].fillna(df["CHAS"].mean(),inplace=True)
df["AGE"].fillna(df["AGE"].mean(),inplace=True)
df["LSTAT"].fillna(df["LSTAT"].mean(),inplace=True)
df
# Out:
# C:\Users\sujal\AppData\Local\Temp\ipykernel_11620\176569600.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["CRIM"].fillna(df["CRIM"].mean(),inplace=True)
# C:\Users\sujal\AppData\Local\Temp\ipykernel_11620\176569600.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["ZN"].fillna(df["ZN"].mean(),inplace=True)
# C:\Users\sujal\AppData\Local\Temp\ipykernel_11620\176569600.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["INDUS"].fillna(df["INDUS"].mean(),inplace=True)
# C:\Users\sujal\AppData\Local\Temp\ipykernel_11620\176569600.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["CHAS"].fillna(df["CHAS"].mean(),inplace=True)
# C:\Users\sujal\AppData\Local\Temp\ipykernel_11620\176569600.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["AGE"].fillna(df["AGE"].mean(),inplace=True)
# C:\Users\sujal\AppData\Local\Temp\ipykernel_11620\176569600.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["LSTAT"].fillna(df["LSTAT"].mean(),inplace=True)
#         CRIM    ZN  INDUS  CHAS    NOX     RM        AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.200000  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.900000  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.100000  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.800000  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.200000  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...        ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.100000  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.700000  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.000000  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.300000  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  68.518519  2.5050    1  273
#
#      PTRATIO       B      LSTAT  MEDV
# 0       15.3  396.90   4.980000  24.0
# 1       17.8  396.90   9.140000  21.6
# 2       17.8  392.83   4.030000  34.7
# 3       18.7  394.63   2.940000  33.4
# 4       18.7  396.90  12.715432  36.2
# ..       ...     ...        ...   ...
# 501     21.0  391.99  12.715432  22.4
# 502     21.0  396.90   9.080000  20.6
# 503     21.0  396.90   5.640000  23.9
# 504     21.0  393.45   6.480000  22.0
# 505     21.0  396.90   7.880000  11.9
#
# [506 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
x= df.drop(['MEDV'], axis=1)
x
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM        AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.200000  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.900000  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.100000  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.800000  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.200000  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...        ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.100000  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.700000  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.000000  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.300000  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  68.518519  2.5050    1  273
#
#      PTRATIO       B      LSTAT
# 0       15.3  396.90   4.980000
# 1       17.8  396.90   9.140000
# 2       17.8  392.83   4.030000
# 3       18.7  394.63   2.940000
# 4       18.7  396.90  12.715432
# ..       ...     ...        ...
# 501     21.0  391.99  12.715432
# 502     21.0  396.90   9.080000
# 503     21.0  396.90   5.640000
# 504     21.0  393.45   6.480000
# 505     21.0  396.90   7.880000
#
# [506 rows x 13 columns]

# %%
y=df['MEDV']
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# Assuming you have defined your features as x and labels as y
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
xtrain
# Out:
#          CRIM         ZN  INDUS  CHAS     NOX     RM        AGE     DIS  RAD  \
# 477  15.02340   0.000000  18.10   0.0  0.6140  5.304  97.300000  2.1007   24
# 15    0.62739   0.000000   8.14   0.0  0.5380  5.834  56.500000  4.4986    4
# 332   0.03466  11.211934   6.06   0.0  0.4379  6.031  23.300000  6.6407    1
# 423   7.05042   0.000000  18.10   0.0  0.6140  6.103  68.518519  2.0218   24
# 19    0.72580   0.000000   8.14   0.0  0.5380  5.727  69.500000  3.7965    4
# ..        ...        ...    ...   ...     ...    ...        ...     ...  ...
# 106   0.17120   0.000000   8.56   0.0  0.5200  5.836  91.900000  2.2110    5
# 270   0.29916  20.000000   6.96   0.0  0.4640  5.856  42.100000  4.4290    3
# 348   0.01501  80.000000   2.01   0.0  0.4350  6.635  29.700000  8.3440    4
# 435  11.16040   0.000000  18.10   0.0  0.7400  6.629  94.600000  2.1247   24
# 102   0.22876   0.000000   8.56   0.0  0.5200  6.405  85.400000  2.7147    5
#
#      TAX  PTRATIO       B  LSTAT
# 477  666     20.2  349.48  24.91
# 15   307     21.0  395.62   8.47
# 332  304     16.9  362.25   7.83
# 423  666     20.2    2.52  23.29
# 19   307     21.0  390.95  11.28
# ..   ...      ...     ...    ...
# 106  384     20.9  395.67  18.66
# 270  223     18.6  388.65  13.00
# 348  280     17.0  390.94   5.99
# 435  666     20.2  109.85  23.27
# 102  384     20.9   70.80  10.63
#
# [404 rows x 13 columns]

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
ytrain_pred = lm.predict(xtrain)
ytest_pred = lm.predict(xtest
#         3.11105960e+01,  2.02837991e+01,  2.43569451e+01,  2.26326769e+01,
#         1.45257750e+01,  3.23698301e+01,  4.30428488e+01,  1.76390763e+01,
#         2.76326197e+01,  1.64305143e+01,  1.42484248e+01,  2.61635938e+01,
#         1.97678160e+01,  3.01463483e+01,  2.09688785e+01,  3.38338873e+01,
#         1.64161397e+01,  2.63964842e+01,  3.97974153e+01,  2.20563187e+01,
#         1.86348862e+01,  3.28326904e+01,  2.54125467e+01,  1.30089663e+01,
#         2.27876091e+01,  3.07563535e+01,  3.14152535e+01,  1.63140433e+01,
#         2.03393413e+01,  1.71517970e+01,  2.01806664e+01,  2.61876399e+01,
#         3.09535452e+01,  1.13750175e+01,  2.09535826e+01,  2.65775894e+01,
#         1.10320126e+01,  1.28353764e+01,  2.37619366e+01,  6.45053524e+00,
#         2.16940761e+01,  4.17751699e+01,  1.87002180e+01,  8.80916013e+00,
#         2.09823382e+01,  1.32224442e+01,  2.09744123e+01,  9.19727517e+00,
#         2.29748473e+01,  3.23665383e+01,  1.90112841e+01,  2.56021909e+01,
#         2.86884146e+01,  1.97639493e+01,  2.59912517e+01,  5.78236486e+00,
#         1.94886094e+01,  1.52277879e+01,  1.07368355e+01,  2.00495289e+01,
#         2.37375593e+01,  2.87336882e-02,  1.35379379e+01,  1.60971385e+01,
#         2.27958041e+01,  2.43808232e+01])

# %%
ytrain
# Out:
# 477    12.0
# 15     19.9
# 332    19.4
# 423    13.4
# 19     18.2
#        ...
# 106    19.5
# 270    21.1
# 348    24.5
# 435    13.4
# 102    18.6
# Name: MEDV, Length: 404, dtype: float64

# %%
df1=pd.DataFrame(ytrain_pred,ytrain)
df2=pd.DataFrame(ytest_pred,ytest)

# %%
df1
# Out:
#               0
# MEDV
# 12.0  10.702220
# 19.9  19.393055
# 19.4  22.633864
# 13.4  12.546925
# 18.2  18.398586
# ...         ...
# 19.5  17.661084
# 21.1  22.320419
# 24.5  26.900199
# 13.4  13.218612
# 18.6  19.256008
#
# [404 rows x 1 columns]

# %%
df2
# Out:
#               0
# MEDV
# 23.6  29.143250
# 32.4  36.535668
# 13.6  14.492513
# 22.8  25.081110
# 16.1  18.456092
# ...         ...
# 17.9   0.028734
# 9.6   13.537938
# 17.2  16.097139
# 22.5  22.795804
# 21.4  24.380823
#
# [102 rows x 1 columns]

# %%
from sklearn.metrics import mean_squared_error, r2_score
mse=mean_squared_error(ytest,ytest_pred)
print(mse)
# Out:
# 25.017672023842703

# %%
mse=mean_squared_error(ytrain_pred,ytrain)
print(mse)
# Out:
# 22.410733172287667

# %%
import matplotlib.pyplot as plt

# Assuming you have defined ytrain_pred and ytest_pred

# Scatter plot for training data
plt.scatter(ytrain, ytrain_pred, c='blue', marker='o', label='Training data')

# Scatter plot for test data
plt.scatter(ytest, ytest_pred, c='lightgreen', marker='s', label='Test data')

plt.xlabel('True values')
plt.ylabel('Predicted')
plt.title("True value vs Predicted value")
plt.legend(loc='upper left')
plt.show()
